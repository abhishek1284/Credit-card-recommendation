# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\DELL\Desktop\credit_risk_dataset.csv")
data
# Out:
#        Unnamed: 0  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
data.dropna()
# Out:
#        Unnamed: 0  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
data.rename(columns={'Unnamed: 0': 'person_id'}, inplace=True)

# %%
data
# Out:
#        person_id  person_income person_home_ownership  person_emp_length  \
# 0             22          59000                  RENT              123.0
# 1             21           9600                   OWN                5.0
# 2             25           9600              MORTGAGE                1.0
# 3             23          65500                  RENT                4.0
# 4             24          54400                  RENT                8.0
# ...          ...            ...                   ...                ...
# 32576         57          53000              MORTGAGE                1.0
# 32577         54         120000              MORTGAGE                4.0
# 32578         65          76000                  RENT                3.0
# 32579         56         150000              MORTGAGE                5.0
# 32580         66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data = data.dropna().reset_index(drop=True)

# %%
data
# Out:
#        person_id  person_income person_home_ownership  person_emp_length  \
# 0             22          59000                  RENT              123.0
# 1             21           9600                   OWN                5.0
# 2             25           9600              MORTGAGE                1.0
# 3             23          65500                  RENT                4.0
# 4             24          54400                  RENT                8.0
# ...          ...            ...                   ...                ...
# 28633         57          53000              MORTGAGE                1.0
# 28634         54         120000              MORTGAGE                4.0
# 28635         65          76000                  RENT                3.0
# 28636         56         150000              MORTGAGE                5.0
# 28637         66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

data.to_csv("cleaned_data.csv", index=False)

# %%
data.describe()
# Out:
#          Unnamed: 0  person_income  person_emp_length     loan_amnt  \
# count  28638.000000   2.863800e+04       28638.000000  28638.000000
# mean      27.727216   6.664937e+04           4.788672   9656.493121
# std        6.310441   6.235645e+04           4.154627   6329.683361
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.948000e+04           2.000000   5000.000000
# 50%       26.000000   5.595600e+04           4.000000   8000.000000
# 75%       30.000000   8.000000e+04           7.000000  12500.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   28638.000000  28638.000000         28638.000000
# mean       11.039867      0.216600             0.169488
# std         3.229372      0.411935             0.106393
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
# 1. Correlation between income and loan amount / interest rate
corr_income_loan_amnt = data['person_income'].corr(data['loan_amnt'])
corr_income_int_rate = data['person_income'].corr(data['loan_int_rate'])

print(f"Correlation between person_income and loan_amnt: {corr_income_loan_amnt:.3f}")
print(f"Correlation between person_income and loan_int_rate: {corr_income_int_rate:.3f}")

# 2. Scatter plot: Income vs Loan Amount
plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x='person_income', y='loan_amnt', alpha=0.5)
plt.title('Person Income vs Loan Amount')
plt.xlabel('Person Income')
plt.ylabel('Loan Amount')
plt.show
# Out:
# Correlation between person_income and loan_amnt: 0.266
# Correlation between person_income and loan_int_rate: -0.001
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data
# Out:
#        Unnamed: 0  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 28633          57          53000                1.0       5800          13.16
# 28634          54         120000                4.0      17625           7.49
# 28635          65          76000                3.0      35000          10.99
# 28636          56         150000                5.0      15000          11.48
# 28637          66          42000                2.0       6475           9.99
#
# ...

# %%
#Scatter plot with regression line
plt.figure(figsize=(8, 5))
sns.regplot(data=data, x='person_income', y='loan_int_rate', scatter_kws={'alpha':0.5}, line_kws={"color": "red"})
plt.title('Person Income vs Loan Interest Rate with Regression Line')
plt.xlabel('Person Income')
plt.ylabel('Loan Interest Rate (%)')
plt.show()

# %%
# 1. Distribution of Loan Grades
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='loan_grade', order=sorted(data['loan_grade'].unique()))
plt.title('Distribution of Loan Grades')
plt.xlabel('Loan Grade')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3. Interest Rate Trends by Loan Grade
interest_by_grade = data.groupby('loan_grade')['loan_int_rate'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=interest_by_grade, x='loan_grade', y='loan_int_rate', order=sorted(data['loan_grade'].unique()))
plt.title('Average Interest Rate by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Average Interest Rate (%)')
plt.savefig("loan_grade.png")
plt.show()

# %%
data
# Out:
#        person_id  person_income person_home_ownership  person_emp_length  \
# 0             22          59000                  RENT              123.0
# 1             21           9600                   OWN                5.0
# 2             25           9600              MORTGAGE                1.0
# 3             23          65500                  RENT                4.0
# 4             24          54400                  RENT                8.0
# ...          ...            ...                   ...                ...
# 28633         57          53000              MORTGAGE                1.0
# 28634         54         120000              MORTGAGE                4.0
# 28635         65          76000                  RENT                3.0
# 28636         56         150000              MORTGAGE                5.0
# 28637         66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
# Calculate correlation values
corr_income_loan = data['person_income'].corr(data['loan_amnt'])
corr_income_interest = data['person_income'].corr(data['loan_int_rate'])
corr_credit_history_interest = data['cb_person_cred_hist_length'].corr(data['loan_int_rate'])

print(f"Correlation: Income vs Loan Amount = {corr_income_loan:.3f}")
print(f"Correlation: Income vs Interest Rate = {corr_income_interest:.3f}")
print(f"Correlation: Credit History Length vs Interest Rate = {corr_credit_history_interest:.3f}")
# Out:
# Correlation: Income vs Loan Amount = 0.266
# Correlation: Income vs Interest Rate = -0.001
# Correlation: Credit History Length vs Interest Rate = 0.015

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Income vs Loan Amount
plt.figure(figsize=(8, 5))
sns.regplot(data=data, x='person_income', y='loan_amnt', scatter_kws={'alpha':0.5})
plt.title('Income vs Loan Amount')
plt.xlabel('Person Income')
plt.ylabel('Loan Amount')
plt.grid(True, linestyle='--', alpha=0.5)
plt.savefig("income.png")
plt.show()

# Income vs Interest Rate
plt.figure(figsize=(8, 5))
sns.regplot(data=data, x='person_income', y='loan_int_rate', scatter_kws={'alpha':0.5}, line_kws={"color": "red"})
plt.title('Income vs Interest Rate')
plt.xlabel('Person Income')
plt.ylabel('Loan Interest Rate (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# Credit History vs Interest Rate
plt.figure(figsize=(8, 5))
sns.regplot(data=data, x='cb_person_cred_hist_length', y='loan_int_rate', scatter_kws={'alpha':0.5}, line_kws={"color": "green"})
plt.title('Credit History Length vs Interest Rate')
plt.xlabel('Credit History Length (Years)')
plt.ylabel('Loan Interest Rate (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by loan_grade and calculate mean income
avg_income_by_loan_grade = data.groupby('loan_grade')['person_income'].mean().sort_index()

# Plot average income by loan grade
plt.figure(figsize=(8,5))
avg_income_by_loan_grade.plot(kind='bar', color='coral')

plt.title('Average Person Income by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Average Income')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
avg_income_by_loan_grade = data.groupby('loan_grade')['person_income'].mean().sort_index()

print(avg_income_by_loan_grade.reset_index().rename(columns={'person_income': 'Average Income'}))
# Out:
#   loan_grade  Average Income
# 0          A    67028.700596
# 1          B    66796.502240
# 2          C    65847.889454
# 3          D    64242.658559
# 4          E    71174.186207
# 5          F    80079.229665
# 6          G    78994.898305

# %%
data.columns
# Out:
# Index(['person_id', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
# --- 1. Distribution Analysis ---
plt.figure(figsize=(10, 5))
sns.histplot(data['person_emp_length'].dropna(), bins=20, kde=True)
plt.title('Distribution of Employment Length (Years)')
plt.xlabel('Employment Length (Years)')
plt.ylabel('Frequency')
plt.show()

# --- 2. Binning the Employment Length ---
bins = [0, 2, 5, 10, 20, data['person_emp_length'].max()]
labels = ['0-2 yrs', '3-5 yrs', '6-10 yrs', '11-20 yrs', '21+ yrs']
data['emp_length_bin'] = pd.cut(data['person_emp_length'], bins=bins, labels=labels, right=False)

# --- 3. Impact on Default Rate ---
# Assume 'loan_status' is 1 for default, 0 for paid
default_rate = data.groupby('emp_length_bin')['loan_status'].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.barplot(x='emp_length_bin', y='loan_status', data=default_rate)
plt.title('Default Rate by Employment Length Bin')
plt.ylabel('Default Rate')
plt.xlabel('Employment Length Bin')
plt.ylim(0, 1)
plt.show()

# --- 4. Correlation with Loan Status ---
correlation = data[['person_emp_length', 'loan_status']].corr()
print("Correlation between employment length and loan status:")
print(correlation)

# Optional: Show default rate and count for each bin
summary = data.groupby('emp_length_bin')['loan_status'].agg(['mean', 'count']).reset_index()
print(summary)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5324\2525080532.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   default_rate = data.groupby('emp_length_bin')['loan_status'].mean().reset_index()
# Correlation between employment length and loan status:
#                    person_emp_length  loan_status
# person_emp_length           1.000000    -0.082638
# loan_status                -0.082638     1.000000
#   emp_length_bin      mean  count
# 0        0-2 yrs  0.280856   6352
# 1        3-5 yrs  0.225553   9173
# 2       6-10 yrs  0.184737   9841
# 3      11-20 yrs  0.158163   3136
# 4        21+ yrs  0.261194    134
# ...

# %%
# --- 1. Default Rate by Loan Intent ---
default_rate = data.groupby('loan_intent')['loan_status'].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.barplot(x='loan_intent', y='loan_status', data=default_rate, palette='Set2')
plt.title('Default Rate by Loan Intent')
plt.xlabel('Loan Intent')
plt.ylabel('Default Rate')
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("loan.png")
plt.show()

# --- 2. Frequency and Average Loan Amount ---
loan_stats = data.groupby('loan_intent')['loan_amnt'].agg(['count', 'mean']).reset_index()

fig, ax1 = plt.subplots(figsize=(12, 6))

sns.barplot(x='loan_intent', y='count', data=loan_stats, ax=ax1, color='skyblue')
ax1.set_ylabel('Frequency', color='blue')
ax1.set_xlabel('Loan Intent')
ax1.set_title('Frequency and Average Loan Amount by Loan Intent')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_xticklabels(loan_stats['loan_intent'], rotation=45)

# Create a second y-axis for the average loan amount
ax2 = ax1.twinx()
sns.lineplot(x='loan_intent', y='mean', data=loan_stats, ax=ax2, color='red', marker='o')
ax2.set_ylabel('Average Loan Amount', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.tight_layout()
plt.savefig("freq.png")

plt.show()

# --- 3. One-Hot Encoding for Machine Learning ---
# Create dummy variables for 'loan_intent'
loan_intent_dummies = pd.get_dummies(data['loan_intent'], prefix='intent', drop_first=False)

# Concatenate with the original dataset
data_encoded = pd.concat([data, loan_intent_dummies], axis=1)

# Display result
print("One-hot encoded columns added:")
print(data_encoded.columns)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5324\2635185488.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='loan_intent', y='loan_status', data=default_rate, palette='Set2')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5324\2635185488.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(loan_stats['loan_intent'], rotation=45)
# One-hot encoded columns added:
# Index(['person_id', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length',
#        'emp_length_bin', 'intent_DEBTCONSOLIDATION', 'intent_EDUCATION',
# ...

# %%
# train_model.py
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import joblib

# Load and preprocess data
data=pd.read_csv(r"C:\Users\DELL\Desktop\credit_risk_dataset.csv")
data = pd.get_dummies(data, drop_first=True)
X = data.drop('loan_status', axis=1)
y = data['loan_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Save model and feature names
joblib.dump(model, 'credit_model.pkl')
joblib.dump(X.columns.tolist(), 'model_columns.pkl')
# Out:
# ['model_columns.pkl']

# %%
# train_model.py
import pandas as pd
from sklearn.model_selection import train_test_split
import joblib

# Uncomment if you want both models
# from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# Load and preprocess data
data = pd.read_csv(r"C:\Users\DELL\Desktop\credit_risk_dataset.csv")
data = pd.get_dummies(data, drop_first=True)

X = data.drop('loan_status', axis=1)
y = data['loan_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train XGBoost model
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

# Optional: train Random Forest for comparison
# rf_model = RandomForestClassifier(random_state=42)
# rf_model.fit(X_train, y_train)

# Save model and metadata
joblib.dump(xgb_model, 'credit_model_xgb.pkl')
# If using RF as well:
# joblib.dump(rf_model, 'credit_model_rf.pkl')

joblib.dump(X.columns.tolist(), 'model_columns.pkl')

# Evaluate accuracy
from sklearn.metrics import accuracy_score

y_pred_xgb = xgb_model.predict(X_test)'
print(f"XGBoost Accuracy: {accuracy_score(y_test, y_pred_xgb) * 100:.2f}%")

# If RF used:
# y_pred_rf = rf_model.predict(X_test)
# print(f"Random Forest Accuracy: {accuracy_score(y_test, y_pred_rf) * 100:.2f}%")
# Out:
# XGBoost Accuracy: 93.40%
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:46:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
